# %%
# !pip install scikit-surprise
import pandas as pd
import numpy

# %%
df =pd.read_csv('/content/udemy_output_All_IT__Software_p1_p626.csv')
df
# Out:
#             id                                              title  \
# 0       762616  The Complete SQL Bootcamp 2020: Go from Zero t...
# 1       937678  Tableau 2020 A-Z: Hands-On Tableau Training fo...
# 2      1361790             PMP Exam Prep Seminar -  PMBOK Guide 6
# 3       648826         The Complete Financial Analyst Course 2020
# 4       637930  An Entire MBA in 1 Course:Award Winning Busine...
# ...        ...                                                ...
# 22848  1516977  Fundamental Service Oriented Arch (SOA) Securi...
# 22849  1479824  Linux Certification for Experts - Practice Tes...
# 22850  1879598  SAP SuccessFactors Employee Central Payroll Fu...
# 22851  1940616                  Comptia Linux+ / LPIC-1 (102-400)
# 22852   543712                    Cisco Networking CCNA IPv6 OSPF
#
#                                                      url  is_paid  \
# 0                     /course/the-complete-sql-bootcamp/     True
# ...

# %%
from surprise import Reader, Dataset, SVD
from surprise.model_selection.validation import cross_validate
reader = Reader()
data = Dataset.load_from_df(df[['num_subscribers', 'title', 'rating']], reader)
svd = SVD()

# %%
cross_validate(svd, data, measures=['RMSE', 'MAE'], cv=5, verbose=True)
# Out:
# Evaluating RMSE, MAE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.7368  0.7070  0.7035  0.7080  0.7388  0.7188  0.0156
# MAE (testset)     0.5196  0.5029  0.5067  0.5148  0.5099  0.5108  0.0059
# Fit time          1.29    1.29    1.33    1.42    1.37    1.34    0.05
# Test time         0.03    0.03    0.15    0.04    0.03    0.05    0.05
# {'fit_time': (1.294787883758545,
#   1.2887532711029053,
#   1.328061580657959,
#   1.418605089187622,
#   1.3665711879730225),
#  'test_mae': array([0.51958444, 0.50292839, 0.50672614, 0.51477054, 0.5098824 ]),
#  'test_rmse': array([0.73681499, 0.70697734, 0.70346054, 0.70795098, 0.73883341]),
#  'test_time': (0.030303478240966797,
#   0.02925395965576172,
#   0.14876580238342285,
#   0.035291194915771484,
#   0.029984712600708008)}

# %%
train_set = data.build_full_trainset()
svd.fit(train_set)

# %%
val = df_title.copy()
val['Estimate_Score'] = val['id'].apply(lambda x: svd.predict(1, x).est)
val = val.sort_values(by=['Estimate_Score'], ascending=False)
val
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                    id  \
# id      title                                              url                                                is_paid num_subscribers avg_rating avg_rating_recent rating  num_reviews is_wishlisted num_published_lectures num_published_practice_tests created              published_time       discount_price__amount discount_price__currency discount_price__price_string  price_detail__amount
# ...
